# %%
from pathlib import Path
import glob
import numpy as np
import os
from shapely.geometry import Polygon
from shapely import affinity
import trimesh
import sys
import matplotlib.pyplot as plt
from shapely import make_valid
import matplotlib.pyplot as plt
from data_reader import collectData

# %%
case_path = os.path.join("generated_cases", "case_8b6ba71a")
u, l, a, r = collectData(case_path)
print(f"{u}\n{l}\n{a}\n{r}")
# Out:
# float64
# [ 0.24054015  0.33986987  0.1174536   0.3394658   0.22355131 -0.01324606]
# [-0.10207313 -0.04408416 -0.09232889 -0.08573812 -0.1300241  -0.08823429]
# 3.1975
# 53413.1253

# %%
# Out:
# (np.float64(0.01996342347456513), np.float64(0.07253752632344565))
